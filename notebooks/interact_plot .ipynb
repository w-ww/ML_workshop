# %%
from hana_ml import dataframe
import numpy as np
import pandas as pd
from hdbcli import dbapi
import configparser

# %%
from PALPlot import *

# %%
settings = configparser.ConfigParser()
url = '10.58.121.93'
port = 30115
pwd = 'Abcd1234'
user = 'ADM'
conn = dataframe.ConnectionContext("{}".format(url),int("{}".format(port)), "{}".format(user), "{}".format(pwd))
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-3-6657359d8924> in <module>()
#       5 pwd = 'Abcd1234'
#       6 user = 'ADM'
# ----> 7 conn = dataframe.ConnectionContext("{}".format(url),int("{}".format(port)), "{}".format(user), "{}".format(pwd))
#
# c:\git-work\hanamlapi\src\hana_ml\dataframe.pyc in __init__(self, address, port, user, password, autocommit, packetsize, userkey, **properties)
#      87             packetsize=packetsize,
#      88             userkey=userkey,
# ---> 89             **properties
#      90         )
#      91
#
# C:\anaconda2\Anaconda2\lib\site-packages\hdbcli\dbapi.pyc in __init__(self, address, port, user, password, autocommit, packetsize, userkey, **properties)
#      79
#      80         #connect
# ---> 81         self.__connection = pyhdbcli.connect("%s:%d" % (address, port), 'HDB', user, password, self.__properties)
# ...

# %%
df_pal = dataframe.DataFrame(conn, 'select * from ADM.PAL_ARIMA_DATA_TBL').select('TIMESTAMP','Y')

# %%
print (df_pal.nrows, df_pal.columns)
# Out:
# 1036009 ['TIMESTAMP', 'Y']

# %%
df_pal.head(20).collect()
# Out:
#              TIMESTAMP                                    Y
# 0  1900-01-01 00:00:00  998.2306334882900955562945455312728
# 1  1900-01-01 01:00:00  997.9844135949730343781993724405765
# 2  1900-01-01 02:00:00  998.0765111239458065028884448111057
# 3  1900-01-01 03:00:00  997.9165407258005870971828699111938
# 4  1900-01-01 04:00:00  997.4387589253352643936523236334323
# 5  1900-01-01 05:00:00  995.5056070466483788550249300897121
# 6  1900-01-01 06:00:00  996.4384092894982813959359191358089
# 7  1900-01-01 07:00:00  996.0967563601277561247115954756736
# 8  1900-01-01 08:00:00  997.9297236681935601154691539704799
# 9  1900-01-01 09:00:00  998.3007669276017850279458798468112
# 10 1900-01-01 10:00:00  999.9503416276186271716142073273658
# 11 1900-01-01 11:00:00  1001.746314529743358434643596410751
# 12 1900-01-01 12:00:00  1003.175816241168377018766477704048
# 13 1900-01-01 13:00:00  1002.280375776357686845585703849792
# 14 1900-01-01 14:00:00  1002.908813018216847012809012085199
# ...

# %%
import timeit

# %%
# %matplotlib inline
start=timeit.default_timer()
df_raw = df_pal.collect()
df_raw.set_index(df_raw.columns[0], inplace=True)
df_raw=df_raw.astype(float)
df_raw.plot()
print(timeit.default_timer()-start)
# Out:
# 61.7106938958168

# %%
# %matplotlib inline
start=timeit.default_timer()
df_sample = hana_sample(df_pal,200)
df_mod = df_sample.collect()
df_mod.set_index(df_mod.columns[0], inplace=True)
df_mod=df_mod.astype(float)
df_mod.plot()
print(timeit.default_timer()-start)
# Out:
# 1.0183489713817835

# %%
from PALPlot import *

pal_interact_plot(df_pal)
# Out:
# interactive(children=(SelectionRangeSlider(continuous_update=False, description='Dates', index=(0, 43167), layout=Layout(width='450px'), options=(('1900-01-01', Timestamp('1900-01-01 00:00:00', freq='D')), ('1900-01-02', Timestamp('1900-01-02 00:00:00', freq='D')), ('1900-01-03', Timestamp('1900-01-03 00:00:00', freq='D')), ('1900-01-04', Timestamp('1900-01-04 00:00:00', freq='D')), ('1900-01-05', Timestamp('1900-01-05 00:00:00', freq='D')), ('1900-01-06', Timestamp('1900-01-06 00:00:00', freq='D')), ('1900-01-07', Timestamp('1900-01-07 00:00:00', freq='D')), ('1900-01-08', Timestamp('1900-01-08 00:00:00', freq='D')), ('1900-01-09', Timestamp('1900-01-09 00:00:00', freq='D')), ('1900-01-10', Timestamp('1900-01-10 00:00:00', freq='D')), ('1900-01-11', Timestamp('1900-01-11 00:00:00', freq='D')), ('1900-01-12', Timestamp('1900-01-12 00:00:00', freq='D')), ('1900-01-13', Timestamp('1900-01-13 00:00:00', freq='D')), ('1900-01-14', Timestamp('1900-01-14 00:00:00', freq='D')), ('1900-01-15
# ...

# %%
hana_sample(df_pal.head(20),200)
# Out:
#             TIMESTAMP                                    Y
# 0 1900-01-01 00:00:00  998.2306334882900955562945455312728
# 1 1900-01-01 04:00:00  997.4387589253352643936523236334323
